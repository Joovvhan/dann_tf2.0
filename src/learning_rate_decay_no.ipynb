# %%
from preprocessing import prepare_dataset, prepare_dataset_single
from models import DANN_Model

# %%
(source_train_dataset, source_test_dataset, target_dataset, target_test_dataset) = prepare_dataset('SVHN', 'MNIST')
# (target_dataset_2, target_test_dataset_2) = prepare_dataset('SVHN')

# %%
lp_lr = 0.001
dc_lr = 0.0015
fe_lr = 0.0015
# fe_lr = 0.0000
# fe_lr = 0.00
# fe_lr = 0.000005

lr = (lp_lr, dc_lr, fe_lr)
model = DANN_Model(input_shape=(32, 32, 3), model_type='SVHN', run_name='svhn2m_lr_decay', lr=lr)
# Out:
# Log folder created as ../log/svhn2m_lr_decay_1

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
    for (source_images, class_labels), (target_images, _) in zip(source_train_dataset, target_dataset):
        model.train(source_images, class_labels, target_images)

    for (test_images, test_labels), (target_test_images, _), (target_images, target_labels) in zip(source_test_dataset, target_test_dataset, target_dataset):
        model.test_source(test_images, test_labels, target_test_images)
        model.test_target(target_images, target_labels)
    
    print('Epoch: {}'.format(epoch + 1))
    print(model.log())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0629 20:35:59.742136 20616 deprecation.py:323] From c:\users\jw\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\math_grad.py:1220: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 1
# L1 Test: 2.6922, Acc1 Test: 19.60
# L2 Test: 3.0151, Acc2 Test: 66.96
# L3 Test: 2.7182, Acc3 Test: 9.82
#
# Epoch: 2
# L1 Test: 2.0908, Acc1 Test: 34.32
# L2 Test: 0.6934, Acc2 Test: 52.97
# L3 Test: 1.8806, Acc3 Test: 37.02
#
# Epoch: 3
# L1 Test: 1.9877, Acc1 Test: 32.75
# L2 Test: 1.7718, Acc2 Test: 62.67
# L3 Test: 1.7121, Acc3 Test: 43.79
#
# Epoch: 4
# L1 Test: 1.0031, Acc1 Test: 65.70
# L2 Test: 0.6664, Acc2 Test: 61.33
# L3 Test: 1.6909, Acc3 Test: 53.18
#
# Epoch: 5
# L1 Test: 1.5157, Acc1 Test: 50.85
# L2 Test: 1.2157, Acc2 Test: 61.30
# L3 Test: 1.5504, Acc3 Test: 54.43
#
# Epoch: 6
# L1 Test: 1.8376, Acc1 Test: 38.83
# L2 Test: 0.7984, Acc2 Test: 80.06
# L3 Test: 3.3708, Acc3 Test: 28.90
#
# Epoch: 7
# L1 Test: 2.2069, Acc1 Test: 29.68
# L2 Test: 2.9660, Acc2 Test: 43.93
# L3 Test: 2.2990, Acc3 Test: 41.67
#
# Epoch: 8
# L1 Test: 1.1356, Acc1 Test: 65.75
# L2 Test: 0.7824, Acc2 Test: 58.37
# L3 Test: 1.4540, Acc3 Test: 57.87
#
# Epoch: 9
# L1 Test: 1.0870, Acc1 Test: 67.32
# L2 Test: 1.8297, Acc2 Test: 52.64
# L3 Test: 1.6141, Acc3 Test: 51.12
#
# Epoch: 10
# L1 Test: 1.0961, Acc1 Test: 62.50
# L2 Test: 0.9450, Acc2 Test: 56.37
# L3 Test: 2.0305, Acc3 Test: 51.26
#
# Epoch: 11
# L1 Test: 0.8150, Acc1 Test: 73.67
# L2 Test: 1.2696, Acc2 Test: 61.38
# L3 Test: 1.6450, Acc3 Test: 57.67
#
# Epoch: 12
# L1 Test: 0.7315, Acc1 Test: 76.82
# L2 Test: 0.6770, Acc2 Test: 52.67
# L3 Test: 1.4834, Acc3 Test: 59.48
#
# Epoch: 13
# L1 Test: 0.7064, Acc1 Test: 77.47
# L2 Test: 0.6309, Acc2 Test: 66.45
# L3 Test: 1.6491, Acc3 Test: 52.71
#
# Epoch: 14
# L1 Test: 0.6810, Acc1 Test: 77.27
# L2 Test: 0.8599, Acc2 Test: 53.59
# L3 Test: 1.5915, Acc3 Test: 55.68
#
# Epoch: 15
# L1 Test: 0.6055, Acc1 Test: 81.02
# L2 Test: 1.7656, Acc2 Test: 55.02
# L3 Test: 1.3991, Acc3 Test: 57.52
#
# Epoch: 16
# L1 Test: 0.4705, Acc1 Test: 85.82
# L2 Test: 0.4521, Acc2 Test: 86.12
# L3 Test: 1.6286, Acc3 Test: 49.10
#
# Epoch: 17
# L1 Test: 0.7069, Acc1 Test: 78.38
# L2 Test: 0.9337, Acc2 Test: 69.61
# L3 Test: 1.8220, Acc3 Test: 53.63
#
# Epoch: 18
# L1 Test: 0.4279, Acc1 Test: 87.02
# L2 Test: 0.0597, Acc2 Test: 97.93
# L3 Test: 1.6497, Acc3 Test: 52.47
#
# Epoch: 19
# L1 Test: 0.8908, Acc1 Test: 70.88
# L2 Test: 0.1677, Acc2 Test: 93.64
# L3 Test: 1.6977, Acc3 Test: 51.59
#
# Epoch: 20
# L1 Test: 0.4984, Acc1 Test: 84.13
# L2 Test: 0.3775, Acc2 Test: 87.52
# L3 Test: 1.7234, Acc3 Test: 51.30
#
# Epoch: 21
# L1 Test: 0.4788, Acc1 Test: 85.15
# L2 Test: 0.0809, Acc2 Test: 97.93
# L3 Test: 1.6231, Acc3 Test: 52.25
#
# Epoch: 22
# L1 Test: 0.4144, Acc1 Test: 87.50
# L2 Test: 0.0614, Acc2 Test: 98.08
# L3 Test: 1.6456, Acc3 Test: 51.30
#
# Epoch: 23
# L1 Test: 0.7589, Acc1 Test: 75.55
# L2 Test: 0.0613, Acc2 Test: 97.74
# L3 Test: 1.8110, Acc3 Test: 52.04
#
# Epoch: 24
# L1 Test: 0.4196, Acc1 Test: 87.75
# L2 Test: 0.0924, Acc2 Test: 96.83
# L3 Test: 1.9046, Acc3 Test: 47.78
#
# Epoch: 25
# L1 Test: 0.3995, Acc1 Test: 88.75
# L2 Test: 1.9835, Acc2 Test: 70.67
# L3 Test: 1.7464, Acc3 Test: 50.82
#
# Epoch: 26
# L1 Test: 0.3469, Acc1 Test: 89.77
# L2 Test: 0.0236, Acc2 Test: 98.99
# L3 Test: 1.7535, Acc3 Test: 51.82
#
# Epoch: 27
# L1 Test: 0.3863, Acc1 Test: 88.57
# L2 Test: 0.1295, Acc2 Test: 95.82
# L3 Test: 1.8079, Acc3 Test: 50.64
#
# Epoch: 28
# L1 Test: 0.3374, Acc1 Test: 90.28
# L2 Test: 0.0473, Acc2 Test: 98.27
# L3 Test: 1.7781, Acc3 Test: 52.87
#
# Epoch: 29
# L1 Test: 0.3415, Acc1 Test: 90.05
# L2 Test: 0.0157, Acc2 Test: 99.47
# L3 Test: 1.8063, Acc3 Test: 52.26
#
# Epoch: 30
# L1 Test: 0.3403, Acc1 Test: 90.13
# L2 Test: 0.0075, Acc2 Test: 99.73
# L3 Test: 1.8326, Acc3 Test: 51.77
#
# Epoch: 31
# L1 Test: 0.3325, Acc1 Test: 90.45
# L2 Test: 0.0101, Acc2 Test: 99.68
# L3 Test: 1.8838, Acc3 Test: 53.50
#
# Epoch: 32
# L1 Test: 0.3482, Acc1 Test: 89.98
# L2 Test: 0.0118, Acc2 Test: 99.67
# L3 Test: 1.8969, Acc3 Test: 52.17
#
# Epoch: 33
# L1 Test: 0.3521, Acc1 Test: 89.75
# L2 Test: 0.0066, Acc2 Test: 99.79
# L3 Test: 1.9687, Acc3 Test: 52.27
#
# Epoch: 34
# L1 Test: 0.3534, Acc1 Test: 89.82
# L2 Test: 0.0239, Acc2 Test: 99.20
# L3 Test: 2.1613, Acc3 Test: 49.66
#
# Epoch: 35
# L1 Test: 0.3470, Acc1 Test: 89.98
# L2 Test: 0.0101, Acc2 Test: 99.68
# L3 Test: 2.0424, Acc3 Test: 53.20
#
# Epoch: 36
# L1 Test: 0.3543, Acc1 Test: 89.77
# L2 Test: 0.0118, Acc2 Test: 99.64
# L3 Test: 2.0593, Acc3 Test: 52.73
#
# Epoch: 37
# L1 Test: 0.3646, Acc1 Test: 89.50
# L2 Test: 0.0061, Acc2 Test: 99.85
# L3 Test: 2.0416, Acc3 Test: 53.59
#
# Epoch: 38
# L1 Test: 0.3549, Acc1 Test: 89.83
# L2 Test: 0.0054, Acc2 Test: 99.86
# L3 Test: 2.0626, Acc3 Test: 53.52
#
# Epoch: 39
# L1 Test: 0.3654, Acc1 Test: 90.03
# L2 Test: 0.0094, Acc2 Test: 99.68
# L3 Test: 2.1154, Acc3 Test: 54.07
#
# Epoch: 40
# L1 Test: 0.3803, Acc1 Test: 89.72
# L2 Test: 0.0069, Acc2 Test: 99.75
# L3 Test: 2.2105, Acc3 Test: 53.50
#
# Epoch: 41
# L1 Test: 0.3904, Acc1 Test: 89.30
# L2 Test: 0.0057, Acc2 Test: 99.85
# L3 Test: 2.3224, Acc3 Test: 52.64
#
# Epoch: 42
# L1 Test: 0.3932, Acc1 Test: 89.47
# L2 Test: 0.0137, Acc2 Test: 99.62
# L3 Test: 2.2167, Acc3 Test: 53.84
#
# Epoch: 43
# L1 Test: 0.3835, Acc1 Test: 89.78
# L2 Test: 0.0286, Acc2 Test: 99.11
# L3 Test: 2.3454, Acc3 Test: 52.25
#
# Epoch: 44
# L1 Test: 0.4266, Acc1 Test: 88.65
# L2 Test: 0.0124, Acc2 Test: 99.62
# L3 Test: 2.2781, Acc3 Test: 55.40
#
# Epoch: 45
# L1 Test: 0.4075, Acc1 Test: 89.30
# L2 Test: 0.0125, Acc2 Test: 99.61
# L3 Test: 2.4775, Acc3 Test: 52.95
#
# Epoch: 46
# L1 Test: 0.4138, Acc1 Test: 88.98
# L2 Test: 0.0366, Acc2 Test: 98.92
# L3 Test: 2.6434, Acc3 Test: 51.39
#
# Epoch: 47
# L1 Test: 0.4445, Acc1 Test: 88.73
# L2 Test: 0.0154, Acc2 Test: 99.50
# L3 Test: 2.7700, Acc3 Test: 50.48
#
# Epoch: 48
# L1 Test: 0.3936, Acc1 Test: 90.08
# L2 Test: 0.0153, Acc2 Test: 99.47
# L3 Test: 2.4463, Acc3 Test: 52.59
#
# Epoch: 49
# L1 Test: 1.1375, Acc1 Test: 72.70
# L2 Test: 0.3998, Acc2 Test: 88.76
# L3 Test: 3.0069, Acc3 Test: 48.40
#
# Epoch: 50
# L1 Test: 0.3863, Acc1 Test: 89.75
# L2 Test: 0.0237, Acc2 Test: 99.12
# L3 Test: 2.4709, Acc3 Test: 52.38
