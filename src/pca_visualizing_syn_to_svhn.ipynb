# %%
from preprocessing import prepare_dataset, prepare_dataset_single
from models import DANN_Model

import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import datetime
from openTSNE import TSNE

# %%
(source_train_dataset, source_test_dataset) = prepare_dataset_single('SYN')
# (_, target_test_dataset_1) = prepare_dataset_single('MNIST')
(target_train_dataset, target_test_dataset) = prepare_dataset_single('SVHN')

# %%
lp_lr = 0.002
dc_lr = 0.003
fe_lr = 0.003

lr = (lp_lr, dc_lr, fe_lr)
model = DANN_Model(input_shape=(32, 32, 3), model_type='SVHN', run_name='syn2svhn', lr=lr)
# Out:
# Log folder created as ../log/syn2svhn

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
    
    print(datetime.datetime.now())
    
    for (source_images, class_labels), (target_images, _) in zip(source_train_dataset, target_train_dataset):
        model.train(source_images, class_labels, target_images)
    
    latent_source = []
    latent_target = []
    for (test_images, test_labels), (target_test_images, target_test_labels) in zip(source_test_dataset, target_test_dataset):
        model.test_source(test_images, test_labels, target_test_images)
        model.test_target(target_test_images, target_test_labels)
        
        if len(latent_source) == 0:
            latent_source = model.return_latent_variables(test_images)
        else:
            latent_source = np.concatenate([latent_source, model.return_latent_variables(test_images)])
            
        if len(latent_target) == 0:
            latent_target = model.return_latent_variables(target_test_images)
        else:
            latent_target = np.concatenate([latent_target, model.return_latent_variables(target_test_images)])
            
    print('Epoch: {}'.format(epoch + 1))
    print(model.log())
    
    index = [0, len(latent_source), len(latent_source) + len(latent_target)]  
    latent_variables = np.concatenate([latent_source, latent_target])

    pca_embedding = PCA(n_components=2).fit_transform(latent_variables)

    plt.figure()
    plt.title('Epoch #{}'.format(epoch + 1))
    for i in range(len(index) - 1):
        plt.plot(pca_embedding[index[i]:index[i+1], 0], pca_embedding[index[i]:index[i+1], 1], '.', alpha=0.5)
    plt.legend(['SYN', 'SVHN'])
    plt.show()
# Out:
# 2019-06-30 04:34:17.359838
# WARNING: Logging before flag parsing goes to stderr.
# W0630 04:34:23.412219 25032 deprecation.py:323] From c:\users\jw\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\math_grad.py:1220: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 1
# L1 Test: 0.2727, Acc1 Test: 90.83
# L2 Test: 0.4313, Acc2 Test: 84.52
# L3 Test: 1.4953, Acc3 Test: 50.89
# 2019-06-30 04:34:52.896352
# Epoch: 2
# L1 Test: 0.2690, Acc1 Test: 92.07
# L2 Test: 0.1101, Acc2 Test: 95.97
# L3 Test: 1.0592, Acc3 Test: 67.71
# 2019-06-30 04:35:21.848083
# Epoch: 3
# L1 Test: 0.1959, Acc1 Test: 94.36
# L2 Test: 0.4541, Acc2 Test: 87.21
# L3 Test: 1.4301, Acc3 Test: 59.71
# 2019-06-30 04:35:50.886842
# Epoch: 4
# L1 Test: 0.1029, Acc1 Test: 96.70
# L2 Test: 0.2213, Acc2 Test: 92.09
# L3 Test: 0.8977, Acc3 Test: 74.69
# 2019-06-30 04:36:20.139484
# Epoch: 5
# L1 Test: 0.1074, Acc1 Test: 96.56
# L2 Test: 0.2854, Acc2 Test: 89.17
# L3 Test: 1.2457, Acc3 Test: 66.62
# 2019-06-30 04:36:49.373024
# Epoch: 6
# L1 Test: 0.1054, Acc1 Test: 97.10
# L2 Test: 0.1181, Acc2 Test: 95.56
# L3 Test: 0.9803, Acc3 Test: 74.88
# 2019-06-30 04:37:18.792399
# Epoch: 7
# L1 Test: 0.0676, Acc1 Test: 97.84
# L2 Test: 0.4187, Acc2 Test: 88.63
# L3 Test: 0.8004, Acc3 Test: 79.23
# 2019-06-30 04:37:48.076461
# Epoch: 8
# L1 Test: 0.0930, Acc1 Test: 97.22
# L2 Test: 0.2384, Acc2 Test: 92.54
# L3 Test: 1.0080, Acc3 Test: 75.40
# 2019-06-30 04:38:17.435430
# Epoch: 9
# L1 Test: 0.0803, Acc1 Test: 97.64
# L2 Test: 0.2620, Acc2 Test: 92.37
# L3 Test: 0.9075, Acc3 Test: 78.30
# 2019-06-30 04:38:47.027142
# Epoch: 10
# L1 Test: 0.0962, Acc1 Test: 97.40
# L2 Test: 0.1607, Acc2 Test: 95.20
# L3 Test: 0.8263, Acc3 Test: 80.12
# 2019-06-30 04:39:16.617019
# Epoch: 11
# L1 Test: 0.0827, Acc1 Test: 97.68
# L2 Test: 0.0796, Acc2 Test: 97.07
# L3 Test: 0.9137, Acc3 Test: 78.47
# 2019-06-30 04:39:45.990970
# Epoch: 12
# L1 Test: 0.1053, Acc1 Test: 97.11
# L2 Test: 0.0729, Acc2 Test: 97.72
# L3 Test: 1.0047, Acc3 Test: 76.61
# 2019-06-30 04:40:15.311223
# Epoch: 13
# L1 Test: 0.1043, Acc1 Test: 97.19
# L2 Test: 0.1371, Acc2 Test: 95.62
# L3 Test: 1.0444, Acc3 Test: 76.70
# 2019-06-30 04:40:44.741222
# Epoch: 14
# L1 Test: 0.1017, Acc1 Test: 97.60
# L2 Test: 0.4344, Acc2 Test: 88.84
# L3 Test: 0.8223, Acc3 Test: 81.24
# 2019-06-30 04:41:14.177766
# Epoch: 15
# L1 Test: 0.1357, Acc1 Test: 96.89
# L2 Test: 0.4754, Acc2 Test: 90.47
# L3 Test: 1.0666, Acc3 Test: 78.29
# 2019-06-30 04:41:43.942961
# Epoch: 16
# L1 Test: 0.1004, Acc1 Test: 97.63
# L2 Test: 0.1371, Acc2 Test: 96.59
# L3 Test: 0.9230, Acc3 Test: 79.61
# 2019-06-30 04:42:13.705373
# Epoch: 17
# L1 Test: 0.0814, Acc1 Test: 98.06
# L2 Test: 0.0770, Acc2 Test: 97.79
# L3 Test: 1.0534, Acc3 Test: 76.88
# 2019-06-30 04:42:43.231894
# Epoch: 18
# L1 Test: 0.0742, Acc1 Test: 98.02
# L2 Test: 0.0856, Acc2 Test: 97.97
# L3 Test: 0.8671, Acc3 Test: 81.02
# 2019-06-30 04:43:12.961293
# Epoch: 19
# L1 Test: 0.0849, Acc1 Test: 97.78
# L2 Test: 0.1354, Acc2 Test: 96.39
# L3 Test: 1.0716, Acc3 Test: 76.48
# 2019-06-30 04:43:42.898518
# Epoch: 20
# L1 Test: 0.1090, Acc1 Test: 97.61
# L2 Test: 0.0853, Acc2 Test: 97.82
# L3 Test: 1.1657, Acc3 Test: 77.51
# 2019-06-30 04:44:12.822159
# Epoch: 21
# L1 Test: 0.0747, Acc1 Test: 98.16
# L2 Test: 0.0828, Acc2 Test: 97.76
# L3 Test: 0.9589, Acc3 Test: 80.04
# 2019-06-30 04:44:42.671743
# Epoch: 22
# L1 Test: 0.0771, Acc1 Test: 98.21
# L2 Test: 0.2664, Acc2 Test: 94.72
# L3 Test: 1.1245, Acc3 Test: 76.89
# 2019-06-30 04:45:12.725177
# Epoch: 23
# L1 Test: 0.0855, Acc1 Test: 98.00
# L2 Test: 0.0706, Acc2 Test: 98.50
# L3 Test: 0.9574, Acc3 Test: 81.78
# 2019-06-30 04:45:43.260389
# Epoch: 24
# L1 Test: 0.0815, Acc1 Test: 98.11
# L2 Test: 0.1349, Acc2 Test: 96.76
# L3 Test: 0.9829, Acc3 Test: 79.51
# 2019-06-30 04:46:13.370680
# Epoch: 25
# L1 Test: 0.0942, Acc1 Test: 97.89
# L2 Test: 0.1283, Acc2 Test: 96.91
# L3 Test: 0.9433, Acc3 Test: 80.00
# 2019-06-30 04:46:43.978182
# Epoch: 26
# L1 Test: 0.0815, Acc1 Test: 98.13
# L2 Test: 0.1864, Acc2 Test: 96.21
# L3 Test: 0.9874, Acc3 Test: 80.57
# 2019-06-30 04:47:14.154849
# Epoch: 27
# L1 Test: 0.1164, Acc1 Test: 97.72
# L2 Test: 0.1260, Acc2 Test: 97.27
# L3 Test: 1.1722, Acc3 Test: 78.59
# 2019-06-30 04:47:44.490499
# Epoch: 28
# L1 Test: 0.0851, Acc1 Test: 98.08
# L2 Test: 0.1234, Acc2 Test: 97.10
# L3 Test: 1.1670, Acc3 Test: 76.08
# 2019-06-30 04:48:14.631017
# Epoch: 29
# L1 Test: 0.1011, Acc1 Test: 97.69
# L2 Test: 0.2056, Acc2 Test: 95.52
# L3 Test: 1.0675, Acc3 Test: 77.89
# 2019-06-30 04:48:45.630092
# Epoch: 30
# L1 Test: 0.1178, Acc1 Test: 97.90
# L2 Test: 0.0866, Acc2 Test: 97.87
# L3 Test: 0.9685, Acc3 Test: 81.96
# 2019-06-30 04:49:16.042010
# Epoch: 31
# L1 Test: 0.1092, Acc1 Test: 97.86
# L2 Test: 0.2510, Acc2 Test: 94.43
# L3 Test: 0.9745, Acc3 Test: 79.20
# 2019-06-30 04:49:46.971776
# Epoch: 32
# L1 Test: 0.1193, Acc1 Test: 97.44
# L2 Test: 0.0991, Acc2 Test: 97.56
# L3 Test: 1.0265, Acc3 Test: 78.54
# 2019-06-30 04:50:17.317207
# Epoch: 33
# L1 Test: 0.0830, Acc1 Test: 98.39
# L2 Test: 0.0985, Acc2 Test: 97.86
# L3 Test: 1.0545, Acc3 Test: 81.51
# 2019-06-30 04:50:48.217278
# Epoch: 34
# L1 Test: 0.1016, Acc1 Test: 98.12
# L2 Test: 0.1185, Acc2 Test: 97.42
# L3 Test: 1.0175, Acc3 Test: 81.67
# 2019-06-30 04:51:18.769236
# Epoch: 35
# L1 Test: 0.0825, Acc1 Test: 98.28
# L2 Test: 0.0798, Acc2 Test: 98.21
# L3 Test: 0.9521, Acc3 Test: 80.77
# 2019-06-30 04:51:49.798674
# Epoch: 36
# L1 Test: 0.1093, Acc1 Test: 97.68
# L2 Test: 0.3896, Acc2 Test: 92.82
# L3 Test: 1.2312, Acc3 Test: 74.62
# 2019-06-30 04:52:20.318058
# Epoch: 37
# L1 Test: 0.1246, Acc1 Test: 97.64
# L2 Test: 0.0626, Acc2 Test: 98.47
# L3 Test: 1.1103, Acc3 Test: 79.57
# 2019-06-30 04:52:51.129676
# Epoch: 38
# L1 Test: 0.0915, Acc1 Test: 97.87
# L2 Test: 0.1125, Acc2 Test: 97.64
# L3 Test: 0.9643, Acc3 Test: 80.16
# 2019-06-30 04:53:22.073707
# Epoch: 39
# L1 Test: 0.1303, Acc1 Test: 97.86
# L2 Test: 0.0982, Acc2 Test: 98.01
# L3 Test: 1.1204, Acc3 Test: 81.16
# 2019-06-30 04:53:53.791324
# Epoch: 40
# L1 Test: 0.0769, Acc1 Test: 98.42
# L2 Test: 0.1031, Acc2 Test: 97.67
# L3 Test: 1.0644, Acc3 Test: 81.78
# 2019-06-30 04:54:24.956146
# Epoch: 41
# L1 Test: 0.0767, Acc1 Test: 98.46
# L2 Test: 0.0639, Acc2 Test: 98.57
# L3 Test: 1.0252, Acc3 Test: 82.36
# 2019-06-30 04:54:56.230698
# Epoch: 42
# L1 Test: 0.0839, Acc1 Test: 98.19
# L2 Test: 0.1419, Acc2 Test: 97.12
# L3 Test: 1.0740, Acc3 Test: 78.71
# 2019-06-30 04:55:27.239804
# Epoch: 43
# L1 Test: 0.0953, Acc1 Test: 97.98
# L2 Test: 0.2001, Acc2 Test: 95.42
# L3 Test: 1.1237, Acc3 Test: 80.13
# 2019-06-30 04:55:58.741247
# Epoch: 44
# L1 Test: 0.0832, Acc1 Test: 98.39
# L2 Test: 0.1626, Acc2 Test: 96.98
# L3 Test: 0.8233, Acc3 Test: 84.03
# 2019-06-30 04:56:29.673938
# Epoch: 45
# L1 Test: 0.0932, Acc1 Test: 98.24
# L2 Test: 0.0649, Acc2 Test: 98.58
# L3 Test: 1.2705, Acc3 Test: 79.13
# 2019-06-30 04:57:01.442503
# Epoch: 46
# L1 Test: 0.0830, Acc1 Test: 98.32
# L2 Test: 0.1203, Acc2 Test: 97.29
# L3 Test: 1.1109, Acc3 Test: 81.29
# 2019-06-30 04:57:32.547703
# Epoch: 47
# L1 Test: 0.0762, Acc1 Test: 98.62
# L2 Test: 0.0680, Acc2 Test: 98.48
# L3 Test: 1.1385, Acc3 Test: 80.54
# 2019-06-30 04:58:03.782704
# Epoch: 48
# L1 Test: 0.1036, Acc1 Test: 98.13
# L2 Test: 0.0828, Acc2 Test: 98.12
# L3 Test: 1.3209, Acc3 Test: 77.59
# 2019-06-30 04:58:34.910445
# Epoch: 49
# L1 Test: 0.0992, Acc1 Test: 98.24
# L2 Test: 0.0955, Acc2 Test: 98.13
# L3 Test: 1.1075, Acc3 Test: 80.09
# 2019-06-30 04:59:06.718462
# Epoch: 50
# L1 Test: 0.1291, Acc1 Test: 97.53
# L2 Test: 0.1899, Acc2 Test: 96.61
# L3 Test: 1.2718, Acc3 Test: 75.39

# %%
tsne = TSNE(n_components=2, initialization="pca")

print(datetime.datetime.now())

tsne_embedding = tsne.fit(latent_variables)

print(datetime.datetime.now())

plt.figure()
plt.title('Epoch #{}'.format(epoch + 1))
for i in range(len(index) - 1):
    plt.plot(tsne_embedding[index[i]:index[i+1], 0], tsne_embedding[index[i]:index[i+1], 1], '.', alpha=0.5)
plt.legend(['SYN', 'SVHN'])
plt.show()
# Out:
# 2019-06-30 04:59:37.907720
# 2019-06-30 05:03:53.212380

# %%
plt.figure()
plt.title('Epoch #{}'.format(epoch + 1))
for i in range(1, -1, -1):
    plt.plot(tsne_embedding[index[i]:index[i+1], 0], tsne_embedding[index[i]:index[i+1], 1], '.', alpha=0.5)
plt.legend(['SVHN', 'SYN'])
plt.show()
