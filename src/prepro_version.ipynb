# %%
from preprocessing import prepare_dataset
from models import DANN_Model

# %%
(source_train_dataset, source_test_dataset, target_dataset, target_test_dataset) = prepare_dataset('SYN', 'MNIST')

# %%
lp_lr = 0.00001
dc_lr = 0.00001
fe_lr = 0.00001

lr = (lp_lr, dc_lr, fe_lr)
model = DANN_Model(input_shape=(32, 32, 3), model_type='SVHN', run_name='syn2m', lr=lr)
# Out:
# Log folder created as ../log/syn2m_1

# %%
EPOCHS = 5

for epoch in range(EPOCHS):
    for (source_images, class_labels), (target_images, _) in zip(source_train_dataset, target_dataset):
        model.train(source_images, class_labels, target_images)

    for (test_images, test_labels), (target_test_images, _), (target_images, target_labels) in zip(source_test_dataset, target_test_dataset, target_dataset):
        model.test_source(test_images, test_labels, target_test_images)
        model.test_target(target_images, target_labels)
    
    print('Epoch: {}'.format(epoch + 1))
    print(model.log())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0629 04:34:03.638381 22632 deprecation.py:323] From c:\users\jw\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\math_grad.py:1220: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 1
# L1 Test: 1.6265, Acc1 Test: 46.45
# L2 Test: 0.3916, Acc2 Test: 76.15
# L3 Test: 1.6395, Acc3 Test: 40.58
#
# Epoch: 2
# L1 Test: 0.5603, Acc1 Test: 84.55
# L2 Test: 0.0483, Acc2 Test: 99.20
# L3 Test: 1.2027, Acc3 Test: 59.71
#
# Epoch: 3
# L1 Test: 0.4075, Acc1 Test: 88.22
# L2 Test: 0.0747, Acc2 Test: 97.92
# L3 Test: 1.0578, Acc3 Test: 64.67
#
# Epoch: 4
# L1 Test: 0.3374, Acc1 Test: 90.03
# L2 Test: 0.0147, Acc2 Test: 99.75
# L3 Test: 0.9815, Acc3 Test: 67.05
#
# Epoch: 5
# L1 Test: 0.3080, Acc1 Test: 90.70
# L2 Test: 0.0360, Acc2 Test: 99.35
# L3 Test: 1.0582, Acc3 Test: 65.41

# %%
EPOCHS = 16

for epoch in range(EPOCHS):
    for (source_images, class_labels), (target_images, _) in zip(source_train_dataset, target_dataset):
        model.train(source_images, class_labels, target_images)

    for (test_images, test_labels), (target_test_images, _), (target_images, target_labels) in zip(source_test_dataset, target_test_dataset, target_dataset):
        model.test_source(test_images, test_labels, target_test_images)
        model.test_target(target_images, target_labels)
    
    print('Epoch: {}'.format(epoch + 1))
    print(model.log())
# Out:
# Epoch: 1
# L1 Test: 0.2909, Acc1 Test: 91.30
# L2 Test: 0.3714, Acc2 Test: 81.43
# L3 Test: 0.8762, Acc3 Test: 70.68
#
# Epoch: 2
# L1 Test: 0.2506, Acc1 Test: 92.27
# L2 Test: 0.0073, Acc2 Test: 99.86
# L3 Test: 0.8057, Acc3 Test: 75.08
#
# Epoch: 3
# L1 Test: 0.2244, Acc1 Test: 92.90
# L2 Test: 0.0448, Acc2 Test: 98.76
# L3 Test: 0.7889, Acc3 Test: 75.46
#
# Epoch: 4
# L1 Test: 0.2015, Acc1 Test: 93.67
# L2 Test: 0.0103, Acc2 Test: 99.83
# L3 Test: 0.7434, Acc3 Test: 77.26
#
# Epoch: 5
# L1 Test: 0.1964, Acc1 Test: 93.95
# L2 Test: 0.0087, Acc2 Test: 99.76
# L3 Test: 0.7680, Acc3 Test: 76.61
#
# Epoch: 6
# L1 Test: 0.1734, Acc1 Test: 94.47
# L2 Test: 0.0066, Acc2 Test: 99.84
# L3 Test: 0.6922, Acc3 Test: 78.33
#
# Epoch: 7
# L1 Test: 0.1656, Acc1 Test: 94.78
# L2 Test: 0.0071, Acc2 Test: 99.80
# L3 Test: 0.6663, Acc3 Test: 79.93
#
# Epoch: 8
# L1 Test: 0.1538, Acc1 Test: 95.12
# L2 Test: 0.0114, Acc2 Test: 99.73
# L3 Test: 0.6947, Acc3 Test: 79.51
#
# Epoch: 9
# L1 Test: 0.1482, Acc1 Test: 95.37
# L2 Test: 0.0061, Acc2 Test: 99.86
# L3 Test: 0.6582, Acc3 Test: 80.81
#
# Epoch: 10
# L1 Test: 0.1394, Acc1 Test: 95.45
# L2 Test: 0.0085, Acc2 Test: 99.72
# L3 Test: 0.6179, Acc3 Test: 81.95
#
# Epoch: 11
# L1 Test: 0.1347, Acc1 Test: 95.72
# L2 Test: 0.0091, Acc2 Test: 99.71
# L3 Test: 0.6233, Acc3 Test: 81.79
#
# Epoch: 12
# L1 Test: 0.1275, Acc1 Test: 95.98
# L2 Test: 0.0056, Acc2 Test: 99.88
# L3 Test: 0.6154, Acc3 Test: 81.60
#
# Epoch: 13
# L1 Test: 0.1248, Acc1 Test: 95.98
# L2 Test: 0.0051, Acc2 Test: 99.84
# L3 Test: 0.5945, Acc3 Test: 82.05
#
# Epoch: 14
# L1 Test: 0.1215, Acc1 Test: 96.17
# L2 Test: 0.0032, Acc2 Test: 99.95
# L3 Test: 0.6023, Acc3 Test: 82.18
#
# Epoch: 15
# L1 Test: 0.1150, Acc1 Test: 96.47
# L2 Test: 0.0026, Acc2 Test: 99.96
# L3 Test: 0.6114, Acc3 Test: 82.35
#
# Epoch: 16
# L1 Test: 0.1100, Acc1 Test: 96.57
# L2 Test: 0.0031, Acc2 Test: 99.94
# L3 Test: 0.6207, Acc3 Test: 82.44

# %%
EPOCHS = 16

for epoch in range(EPOCHS):
    for (source_images, class_labels), (target_images, _) in zip(source_train_dataset, target_dataset):
        model.train(source_images, class_labels, target_images)

    for (test_images, test_labels), (target_test_images, _), (target_images, target_labels) in zip(source_test_dataset, target_test_dataset, target_dataset):
        model.test_source(test_images, test_labels, target_test_images)
        model.test_target(target_images, target_labels)
    
    print('Epoch: {}'.format(epoch + 1))
    print(model.log())
# Out:
# Epoch: 1
# L1 Test: 0.1076, Acc1 Test: 96.82
# L2 Test: 0.0032, Acc2 Test: 99.92
# L3 Test: 0.6323, Acc3 Test: 82.28
#
# Epoch: 2
# L1 Test: 0.1067, Acc1 Test: 96.73
# L2 Test: 0.0035, Acc2 Test: 99.93
# L3 Test: 0.5993, Acc3 Test: 83.08
#
# Epoch: 3
# L1 Test: 0.1004, Acc1 Test: 96.83
# L2 Test: 0.0030, Acc2 Test: 99.90
# L3 Test: 0.5925, Acc3 Test: 83.29
#
# Epoch: 4
# L1 Test: 0.0993, Acc1 Test: 96.97
# L2 Test: 0.0035, Acc2 Test: 99.87
# L3 Test: 0.5966, Acc3 Test: 83.29
#
# Epoch: 5
# L1 Test: 0.0980, Acc1 Test: 96.85
# L2 Test: 0.0033, Acc2 Test: 99.90
# L3 Test: 0.5743, Acc3 Test: 83.96
#
# Epoch: 6
# L1 Test: 0.0934, Acc1 Test: 97.05
# L2 Test: 0.0043, Acc2 Test: 99.86
# L3 Test: 0.5693, Acc3 Test: 83.80
#
# Epoch: 7
# L1 Test: 0.0924, Acc1 Test: 97.22
# L2 Test: 0.0048, Acc2 Test: 99.85
# L3 Test: 0.5640, Acc3 Test: 84.10
#
# Epoch: 8
# L1 Test: 0.0898, Acc1 Test: 97.33
# L2 Test: 0.0038, Acc2 Test: 99.87
# L3 Test: 0.5811, Acc3 Test: 83.89
#
# Epoch: 9
# L1 Test: 0.0912, Acc1 Test: 97.20
# L2 Test: 0.0039, Acc2 Test: 99.85
# L3 Test: 0.5834, Acc3 Test: 83.91
#
# Epoch: 10
# L1 Test: 0.0867, Acc1 Test: 97.43
# L2 Test: 0.0050, Acc2 Test: 99.83
# L3 Test: 0.5717, Acc3 Test: 84.33
#
# Epoch: 11
# L1 Test: 0.0862, Acc1 Test: 97.50
# L2 Test: 0.0056, Acc2 Test: 99.82
# L3 Test: 0.5967, Acc3 Test: 83.81
#
# Epoch: 12
# L1 Test: 0.0867, Acc1 Test: 97.32
# L2 Test: 0.0053, Acc2 Test: 99.82
# L3 Test: 0.5937, Acc3 Test: 83.86
#
# Epoch: 13
# L1 Test: 0.0867, Acc1 Test: 97.38
# L2 Test: 0.0051, Acc2 Test: 99.82
# L3 Test: 0.6114, Acc3 Test: 83.44
#
# Epoch: 14
# L1 Test: 0.0825, Acc1 Test: 97.57
# L2 Test: 0.0051, Acc2 Test: 99.84
# L3 Test: 0.6094, Acc3 Test: 83.52
#
# Epoch: 15
# L1 Test: 0.0835, Acc1 Test: 97.47
# L2 Test: 0.0043, Acc2 Test: 99.86
# L3 Test: 0.6313, Acc3 Test: 83.02
#
# Epoch: 16
# L1 Test: 0.0809, Acc1 Test: 97.47
# L2 Test: 0.0037, Acc2 Test: 99.88
# L3 Test: 0.6242, Acc3 Test: 83.33
