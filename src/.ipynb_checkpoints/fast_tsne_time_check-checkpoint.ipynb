# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime
from openTSNE import TSNE

# %%
latent_variables = np.random.random([27000, 6272])

# %%
tsne = TSNE(n_components=2, initialization="pca")

print(datetime.datetime.now())

tsne_embedding = tsne.fit(latent_variables)

print(datetime.datetime.now())

plt.figure()
plt.plot(tsne_embedding[:, 0], tsne_embedding[:, 1], '.')
plt.show()
# Out:
# 2019-06-29 23:42:06.064758
# 2019-06-29 23:48:21.230165
