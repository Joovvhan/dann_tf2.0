# %%
from preprocessing import prepare_dataset, prepare_dataset_single
from models import DANN_Model

import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import datetime
from openTSNE import TSNE

# %%
(source_train_dataset, source_test_dataset) = prepare_dataset_single('SVHN')
# (_, target_test_dataset_1) = prepare_dataset_single('MNIST')
(target_train_dataset, target_test_dataset) = prepare_dataset_single('MNIST')

# %%
lp_lr = 0.002
dc_lr = 0.003
fe_lr = 0.003

lr = (lp_lr, dc_lr, fe_lr)
model = DANN_Model(input_shape=(32, 32, 3), model_type='SVHN', run_name='svhn2mnist', lr=lr)
# Out:
# Log folder created as ../log/svhn2mnist_0

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
    
    print(datetime.datetime.now())
    
    for (source_images, class_labels), (target_images, _) in zip(source_train_dataset, target_train_dataset):
        model.train(source_images, class_labels, target_images)
    
    latent_source = []
    latent_target = []
    for (test_images, test_labels), (target_test_images, target_test_labels) in zip(source_test_dataset, target_test_dataset):
        model.test_source(test_images, test_labels, target_test_images)
        model.test_target(target_test_images, target_test_labels)
        
        if len(latent_source) == 0:
            latent_source = model.return_latent_variables(test_images)
        else:
            latent_source = np.concatenate([latent_source, model.return_latent_variables(test_images)])
            
        if len(latent_target) == 0:
            latent_target = model.return_latent_variables(target_test_images)
        else:
            latent_target = np.concatenate([latent_target, model.return_latent_variables(target_test_images)])
            
    print('Epoch: {}'.format(epoch + 1))
    print(model.log())
    
    index = [0, len(latent_source), len(latent_source) + len(latent_target)]  
    latent_variables = np.concatenate([latent_source, latent_target])

    pca_embedding = PCA(n_components=2).fit_transform(latent_variables)

    plt.figure()
    plt.title('Epoch #{}'.format(epoch + 1))
    for i in range(len(index) - 1):
        plt.plot(pca_embedding[index[i]:index[i+1], 0], pca_embedding[index[i]:index[i+1], 1], '.', alpha=0.5)
    plt.legend(['SVHN', 'MNIST'])
    plt.show()
# Out:
# 2019-06-30 23:34:22.957131
# Epoch: 1
# L1 Test: 2.3465, Acc1 Test: 14.71
# L2 Test: 1.2168, Acc2 Test: 84.05
# L3 Test: 2.5377, Acc3 Test: 13.04
# 2019-06-30 23:35:03.308273
# Epoch: 2
# L1 Test: 5.5241, Acc1 Test: 7.07
# L2 Test: 85.5327, Acc2 Test: 50.00
# L3 Test: 4.3042, Acc3 Test: 9.76
# 2019-06-30 23:35:36.285745
# Epoch: 3
# L1 Test: 2.8210, Acc1 Test: 16.43
# L2 Test: 2.3616, Acc2 Test: 82.36
# L3 Test: 2.2382, Acc3 Test: 17.10
# 2019-06-30 23:36:08.683085
# Epoch: 4
# L1 Test: 2.0591, Acc1 Test: 28.51
# L2 Test: 0.3812, Acc2 Test: 89.52
# L3 Test: 1.8259, Acc3 Test: 31.94
# 2019-06-30 23:36:41.175448
# Epoch: 5
# L1 Test: 2.2794, Acc1 Test: 29.24
# L2 Test: 6.2701, Acc2 Test: 51.98
# L3 Test: 2.4743, Acc3 Test: 37.89
# 2019-06-30 23:37:13.972877
# Epoch: 6
# L1 Test: 1.4767, Acc1 Test: 50.69
# L2 Test: 2.0795, Acc2 Test: 48.06
# L3 Test: 2.1401, Acc3 Test: 51.01
# 2019-06-30 23:37:47.072375
# Epoch: 7
# L1 Test: 2.0724, Acc1 Test: 39.18
# L2 Test: 0.4292, Acc2 Test: 83.07
# L3 Test: 1.2729, Acc3 Test: 59.49
# 2019-06-30 23:38:19.855803
# Epoch: 8
# L1 Test: 1.5062, Acc1 Test: 46.98
# L2 Test: 1.6170, Acc2 Test: 62.50
# L3 Test: 1.7562, Acc3 Test: 47.99
# 2019-06-30 23:38:52.372170
# Epoch: 9
# L1 Test: 1.1370, Acc1 Test: 65.32
# L2 Test: 0.4639, Acc2 Test: 76.39
# L3 Test: 1.5065, Acc3 Test: 51.47
# 2019-06-30 23:39:25.210611
# Epoch: 10
# L1 Test: 0.9884, Acc1 Test: 67.20
# L2 Test: 0.2902, Acc2 Test: 86.75
# L3 Test: 1.5239, Acc3 Test: 50.92
# 2019-06-30 23:39:57.985037
# Epoch: 11
# L1 Test: 1.5141, Acc1 Test: 48.53
# L2 Test: 13.6175, Acc2 Test: 52.91
# L3 Test: 2.0272, Acc3 Test: 40.20
# 2019-06-30 23:40:30.951506
# Epoch: 12
# L1 Test: 1.8467, Acc1 Test: 34.27
# L2 Test: 1.1736, Acc2 Test: 53.68
# L3 Test: 1.5037, Acc3 Test: 48.53
# 2019-06-30 23:41:04.975214
# Epoch: 13
# L1 Test: 1.0961, Acc1 Test: 62.99
# L2 Test: 0.6524, Acc2 Test: 79.51
# L3 Test: 1.4816, Acc3 Test: 52.88
# 2019-06-30 23:41:39.057936
# Epoch: 14
# L1 Test: 1.2406, Acc1 Test: 58.06
# L2 Test: 0.2882, Acc2 Test: 90.63
# L3 Test: 1.7316, Acc3 Test: 47.02
# 2019-06-30 23:42:12.984623
# Epoch: 15
# L1 Test: 1.0031, Acc1 Test: 69.31
# L2 Test: 0.5745, Acc2 Test: 81.04
# L3 Test: 1.2820, Acc3 Test: 55.81
# 2019-06-30 23:42:46.998329
# Epoch: 16
# L1 Test: 1.0570, Acc1 Test: 67.29
# L2 Test: 0.0697, Acc2 Test: 98.45
# L3 Test: 2.5319, Acc3 Test: 45.60
# 2019-06-30 23:43:20.692963
# Epoch: 17
# L1 Test: 0.9706, Acc1 Test: 70.10
# L2 Test: 0.5127, Acc2 Test: 87.87
# L3 Test: 1.4555, Acc3 Test: 54.41
# 2019-06-30 23:43:55.061750
# Epoch: 18
# L1 Test: 0.9436, Acc1 Test: 67.47
# L2 Test: 6.5440, Acc2 Test: 50.58
# L3 Test: 1.6576, Acc3 Test: 48.32
# 2019-06-30 23:44:28.702371
# Epoch: 19
# L1 Test: 0.7406, Acc1 Test: 79.90
# L2 Test: 0.1102, Acc2 Test: 95.96
# L3 Test: 1.8783, Acc3 Test: 51.96
# 2019-06-30 23:45:03.046153
# Epoch: 20
# L1 Test: 1.0718, Acc1 Test: 65.12
# L2 Test: 0.3054, Acc2 Test: 92.85
# L3 Test: 1.5906, Acc3 Test: 53.22
# 2019-06-30 23:45:36.680773
# Epoch: 21
# L1 Test: 0.8225, Acc1 Test: 71.49
# L2 Test: 13.1797, Acc2 Test: 50.00
# L3 Test: 1.2871, Acc3 Test: 61.21
# 2019-06-30 23:46:11.115575
# Epoch: 22
# L1 Test: 0.7122, Acc1 Test: 77.79
# L2 Test: 0.9921, Acc2 Test: 83.04
# L3 Test: 2.4160, Acc3 Test: 44.66
# 2019-06-30 23:46:45.711413
# Epoch: 23
# L1 Test: 1.3083, Acc1 Test: 60.09
# L2 Test: 0.7947, Acc2 Test: 65.73
# L3 Test: 1.7032, Acc3 Test: 55.76
# 2019-06-30 23:47:19.928165
# Epoch: 24
# L1 Test: 0.5533, Acc1 Test: 82.63
# L2 Test: 5.2319, Acc2 Test: 50.07
# L3 Test: 1.6562, Acc3 Test: 60.89
# 2019-06-30 23:47:54.686040
# Epoch: 25
# L1 Test: 0.8935, Acc1 Test: 76.16
# L2 Test: 1.1137, Acc2 Test: 80.68
# L3 Test: 1.2773, Acc3 Test: 58.79
# 2019-06-30 23:48:28.436687
# Epoch: 26
# L1 Test: 0.4376, Acc1 Test: 86.96
# L2 Test: 2.3310, Acc2 Test: 61.84
# L3 Test: 1.4612, Acc3 Test: 58.16
# 2019-06-30 23:49:03.385605
# Epoch: 27
# L1 Test: 0.5968, Acc1 Test: 83.31
# L2 Test: 0.2116, Acc2 Test: 92.08
# L3 Test: 1.3850, Acc3 Test: 54.82
# 2019-06-30 23:49:37.720384
# Epoch: 28
# L1 Test: 1.0783, Acc1 Test: 64.41
# L2 Test: 6.0340, Acc2 Test: 54.36
# L3 Test: 1.8313, Acc3 Test: 50.46
# 2019-06-30 23:50:12.609289
# Epoch: 29
# L1 Test: 2.0049, Acc1 Test: 30.07
# L2 Test: 14.4861, Acc2 Test: 50.00
# L3 Test: 1.9729, Acc3 Test: 31.19
# 2019-06-30 23:50:46.310925
# Epoch: 30
# L1 Test: 0.5367, Acc1 Test: 86.30
# L2 Test: 0.1255, Acc2 Test: 97.87
# L3 Test: 1.4467, Acc3 Test: 56.69
# 2019-06-30 23:51:20.306625
# Epoch: 31
# L1 Test: 0.4299, Acc1 Test: 87.07
# L2 Test: 1.5674, Acc2 Test: 69.43
# L3 Test: 1.4216, Acc3 Test: 59.56
# 2019-06-30 23:51:55.319560
# Epoch: 32
# L1 Test: 1.0048, Acc1 Test: 67.52
# L2 Test: 1.6311, Acc2 Test: 81.62
# L3 Test: 1.2726, Acc3 Test: 59.36
# 2019-06-30 23:52:28.751134
# Epoch: 33
# L1 Test: 1.1201, Acc1 Test: 61.46
# L2 Test: 0.6394, Acc2 Test: 93.51
# L3 Test: 2.4341, Acc3 Test: 44.57
# 2019-06-30 23:53:01.951656
# Epoch: 34
# L1 Test: 0.5262, Acc1 Test: 84.07
# L2 Test: 2.1241, Acc2 Test: 51.04
# L3 Test: 1.2546, Acc3 Test: 63.27
# 2019-06-30 23:53:35.518260
# Epoch: 35
# L1 Test: 0.4670, Acc1 Test: 87.22
# L2 Test: 0.2346, Acc2 Test: 95.61
# L3 Test: 1.5269, Acc3 Test: 49.08
# 2019-06-30 23:54:09.008849
# Epoch: 36
# L1 Test: 0.4030, Acc1 Test: 88.47
# L2 Test: 1.3243, Acc2 Test: 77.70
# L3 Test: 1.5433, Acc3 Test: 53.46
# 2019-06-30 23:54:42.994549
# Epoch: 37
# L1 Test: 1.0989, Acc1 Test: 65.13
# L2 Test: 0.8273, Acc2 Test: 74.39
# L3 Test: 1.6089, Acc3 Test: 55.24
# 2019-06-30 23:55:16.526145
# Epoch: 38
# L1 Test: 0.7582, Acc1 Test: 74.74
# L2 Test: 0.0801, Acc2 Test: 98.18
# L3 Test: 1.7210, Acc3 Test: 52.64
# 2019-06-30 23:55:50.746898
# Epoch: 39
# L1 Test: 1.2487, Acc1 Test: 64.19
# L2 Test: 2.5633, Acc2 Test: 56.18
# L3 Test: 2.0224, Acc3 Test: 53.42
# 2019-06-30 23:56:24.654582
# Epoch: 40
# L1 Test: 0.5340, Acc1 Test: 84.94
# L2 Test: 0.8797, Acc2 Test: 71.80
# L3 Test: 1.8656, Acc3 Test: 49.54
# 2019-06-30 23:56:58.831325
# Epoch: 41
# L1 Test: 0.7052, Acc1 Test: 77.32
# L2 Test: 1.2733, Acc2 Test: 61.68
# L3 Test: 2.8459, Acc3 Test: 35.71
# 2019-06-30 23:57:32.897043
# Epoch: 42
# L1 Test: 0.4465, Acc1 Test: 86.63
# L2 Test: 0.1267, Acc2 Test: 96.29
# L3 Test: 1.7421, Acc3 Test: 53.83
# 2019-06-30 23:58:07.064784
# Epoch: 43
# L1 Test: 1.3571, Acc1 Test: 56.92
# L2 Test: 0.8837, Acc2 Test: 75.08
# L3 Test: 2.0774, Acc3 Test: 47.63
# 2019-06-30 23:58:40.874444
# Epoch: 44
# L1 Test: 0.6495, Acc1 Test: 80.16
# L2 Test: 0.8090, Acc2 Test: 72.78
# L3 Test: 2.3587, Acc3 Test: 33.71
# 2019-06-30 23:59:15.938388
# Epoch: 45
# L1 Test: 0.7428, Acc1 Test: 76.38
# L2 Test: 0.3674, Acc2 Test: 89.49
# L3 Test: 1.8549, Acc3 Test: 47.12
# 2019-06-30 23:59:52.478666
# Epoch: 46
# L1 Test: 0.6904, Acc1 Test: 79.87
# L2 Test: 0.3436, Acc2 Test: 91.94
# L3 Test: 2.0691, Acc3 Test: 39.02
# 2019-07-01 00:00:27.491600
# Epoch: 47
# L1 Test: 1.1464, Acc1 Test: 60.46
# L2 Test: 0.5380, Acc2 Test: 94.05
# L3 Test: 1.9305, Acc3 Test: 48.54
# 2019-07-01 00:01:02.544542
# Epoch: 48
# L1 Test: 1.3515, Acc1 Test: 57.52
# L2 Test: 1.0052, Acc2 Test: 90.26
# L3 Test: 2.5148, Acc3 Test: 48.56
# 2019-07-01 00:01:37.034357
# Epoch: 49
# L1 Test: 0.9338, Acc1 Test: 71.08
# L2 Test: 1.0690, Acc2 Test: 83.65
# L3 Test: 1.9099, Acc3 Test: 44.89
# 2019-07-01 00:02:11.660201
# Epoch: 50
# L1 Test: 0.5032, Acc1 Test: 85.41
# L2 Test: 0.8552, Acc2 Test: 77.73
# L3 Test: 1.9995, Acc3 Test: 48.43

# %%
tsne = TSNE(n_components=2, initialization="pca")

print(datetime.datetime.now())

tsne_embedding = tsne.fit(latent_variables)

print(datetime.datetime.now())

plt.figure()
plt.title('Epoch #{}'.format(epoch + 1))
for i in range(len(index) - 1):
    plt.plot(tsne_embedding[index[i]:index[i+1], 0], tsne_embedding[index[i]:index[i+1], 1], '.', alpha=0.5)
plt.legend(['SYN', 'MNIST'])
plt.show()
# Out:
# 2019-07-01 00:02:46.474087
# 2019-07-01 00:06:32.113210

# %%
plt.figure()
plt.title('Epoch #{}'.format(epoch + 1))
for i in range(1, -1, -1):
    plt.plot(tsne_embedding[index[i]:index[i+1], 0], tsne_embedding[index[i]:index[i+1], 1], '.', alpha=0.5)
plt.legend(['MNIST', 'SYN'])
plt.show()
