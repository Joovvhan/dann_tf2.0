# %%
from preprocessing import prepare_dataset, prepare_dataset_single
from models import DANN_Model

import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import datetime
from openTSNE import TSNE

# %%
(source_train_dataset, source_test_dataset) = prepare_dataset_single('SVHN')
# (_, target_test_dataset_1) = prepare_dataset_single('MNIST')
(target_train_dataset, target_test_dataset) = prepare_dataset_single('MNIST')

# %%
lp_lr = 0.001
dc_lr = 0.0015
fe_lr = 0.0015

lr = (lp_lr, dc_lr, fe_lr)
model = DANN_Model(input_shape=(32, 32, 3), model_type='SVHN', run_name='svhn2mnist', lr=lr)
# Out:
# Log folder created as ../log/svhn2mnist

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
    
    print(datetime.datetime.now())
    
    for (source_images, class_labels), (target_images, _) in zip(source_train_dataset, target_train_dataset):
        model.train(source_images, class_labels, target_images)
    
    latent_source = []
    latent_target = []
    for (test_images, test_labels), (target_test_images, target_test_labels) in zip(source_test_dataset, target_test_dataset):
        model.test_source(test_images, test_labels, target_test_images)
        model.test_target(target_test_images, target_test_labels)
        
        if len(latent_source) == 0:
            latent_source = model.return_latent_variables(test_images)
        else:
            latent_source = np.concatenate([latent_source, model.return_latent_variables(test_images)])
            
        if len(latent_target) == 0:
            latent_target = model.return_latent_variables(target_test_images)
        else:
            latent_target = np.concatenate([latent_target, model.return_latent_variables(target_test_images)])
            
    print('Epoch: {}'.format(epoch + 1))
    print(model.log())
    
    index = [0, len(latent_source), len(latent_source) + len(latent_target)]  
    latent_variables = np.concatenate([latent_source, latent_target])

    pca_embedding = PCA(n_components=2).fit_transform(latent_variables)

    plt.figure()
    plt.title('Epoch #{}'.format(epoch + 1))
    for i in range(len(index) - 1):
        plt.plot(pca_embedding[index[i]:index[i+1], 0], pca_embedding[index[i]:index[i+1], 1], '.', alpha=0.5)
    plt.legend(['SVHN', 'MNIST'])
    plt.show()
# Out:
# 2019-07-02 15:52:05.071236
# Epoch: 1
# L1 Test: 2.5532, Acc1 Test: 8.36
# L2 Test: 8.7696, Acc2 Test: 50.00
# L3 Test: 2.3287, Acc3 Test: 13.27
# 2019-07-02 15:52:44.146481
# Epoch: 2
# L1 Test: 2.1030, Acc1 Test: 27.64
# L2 Test: 9.6530, Acc2 Test: 51.37
# L3 Test: 1.8403, Acc3 Test: 44.26
# 2019-07-02 15:53:16.964561
# Epoch: 3
# L1 Test: 2.3915, Acc1 Test: 36.04
# L2 Test: 9.1609, Acc2 Test: 50.08
# L3 Test: 1.9966, Acc3 Test: 48.13
# 2019-07-02 15:53:49.877104
# Epoch: 4
# L1 Test: 1.3482, Acc1 Test: 52.89
# L2 Test: 0.7267, Acc2 Test: 81.19
# L3 Test: 1.8635, Acc3 Test: 52.79
# 2019-07-02 15:54:23.002725
# Epoch: 5
# L1 Test: 1.2068, Acc1 Test: 57.43
# L2 Test: 0.5866, Acc2 Test: 72.34
# L3 Test: 1.9137, Acc3 Test: 59.27
# 2019-07-02 15:54:55.883621
# Epoch: 6
# L1 Test: 0.9378, Acc1 Test: 69.64
# L2 Test: 1.6865, Acc2 Test: 23.54
# L3 Test: 1.4113, Acc3 Test: 57.94
# 2019-07-02 15:55:29.255408
# Epoch: 7
# L1 Test: 0.9398, Acc1 Test: 69.76
# L2 Test: 0.5092, Acc2 Test: 75.04
# L3 Test: 3.0855, Acc3 Test: 43.57
# 2019-07-02 15:56:01.986428
# Epoch: 8
# L1 Test: 0.8474, Acc1 Test: 74.00
# L2 Test: 1.1870, Acc2 Test: 58.30
# L3 Test: 1.4050, Acc3 Test: 58.71
# 2019-07-02 15:56:34.853374
# Epoch: 9
# L1 Test: 1.4456, Acc1 Test: 46.49
# L2 Test: 4.1526, Acc2 Test: 15.88
# L3 Test: 1.4666, Acc3 Test: 59.01
# 2019-07-02 15:57:07.973863
# Epoch: 10
# L1 Test: 0.7416, Acc1 Test: 76.47
# L2 Test: 1.1046, Acc2 Test: 75.08
# L3 Test: 1.3638, Acc3 Test: 59.57
# 2019-07-02 15:57:41.377778
# Epoch: 11
# L1 Test: 0.8849, Acc1 Test: 72.52
# L2 Test: 1.0310, Acc2 Test: 51.66
# L3 Test: 1.8685, Acc3 Test: 55.18
# 2019-07-02 15:58:14.552698
# Epoch: 12
# L1 Test: 0.9994, Acc1 Test: 73.36
# L2 Test: 1.0051, Acc2 Test: 51.17
# L3 Test: 1.7686, Acc3 Test: 45.78
# 2019-07-02 15:58:47.969578
# Epoch: 13
# L1 Test: 1.1153, Acc1 Test: 65.10
# L2 Test: 0.5783, Acc2 Test: 67.17
# L3 Test: 1.7203, Acc3 Test: 49.41
# 2019-07-02 15:59:21.595608
# Epoch: 14
# L1 Test: 0.5579, Acc1 Test: 82.13
# L2 Test: 0.2278, Acc2 Test: 92.28
# L3 Test: 1.7985, Acc3 Test: 57.56
# 2019-07-02 15:59:55.107539
# Epoch: 15
# L1 Test: 0.8156, Acc1 Test: 73.76
# L2 Test: 0.5387, Acc2 Test: 67.49
# L3 Test: 1.7679, Acc3 Test: 46.96
# 2019-07-02 16:00:29.105197
# Epoch: 16
# L1 Test: 0.9344, Acc1 Test: 72.00
# L2 Test: 0.7967, Acc2 Test: 52.08
# L3 Test: 1.2873, Acc3 Test: 60.49
# 2019-07-02 16:01:02.970236
# Epoch: 17
# L1 Test: 1.0091, Acc1 Test: 68.98
# L2 Test: 0.4222, Acc2 Test: 80.76
# L3 Test: 1.3781, Acc3 Test: 60.86
# 2019-07-02 16:01:36.803922
# Epoch: 18
# L1 Test: 0.4524, Acc1 Test: 86.57
# L2 Test: 0.2017, Acc2 Test: 91.93
# L3 Test: 1.8450, Acc3 Test: 48.41
# 2019-07-02 16:02:10.704828
# Epoch: 19
# L1 Test: 0.6996, Acc1 Test: 78.62
# L2 Test: 0.5287, Acc2 Test: 67.04
# L3 Test: 1.5651, Acc3 Test: 57.70
# 2019-07-02 16:02:44.091378
# Epoch: 20
# L1 Test: 0.9627, Acc1 Test: 66.76
# L2 Test: 0.7278, Acc2 Test: 52.24
# L3 Test: 1.3519, Acc3 Test: 56.04
# 2019-07-02 16:03:17.584820
# Epoch: 21
# L1 Test: 0.8746, Acc1 Test: 74.51
# L2 Test: 1.0044, Acc2 Test: 54.51
# L3 Test: 1.9841, Acc3 Test: 43.84
# 2019-07-02 16:03:51.581134
# Epoch: 22
# L1 Test: 0.9000, Acc1 Test: 71.94
# L2 Test: 1.1581, Acc2 Test: 48.97
# L3 Test: 1.9009, Acc3 Test: 45.28
# 2019-07-02 16:04:25.032345
# Epoch: 23
# L1 Test: 0.6512, Acc1 Test: 80.12
# L2 Test: 0.4377, Acc2 Test: 85.83
# L3 Test: 1.5743, Acc3 Test: 57.98
# 2019-07-02 16:04:58.407040
# Epoch: 24
# L1 Test: 0.5505, Acc1 Test: 82.62
# L2 Test: 0.1191, Acc2 Test: 97.87
# L3 Test: 1.7838, Acc3 Test: 51.58
# 2019-07-02 16:05:31.891276
# Epoch: 25
# L1 Test: 0.9298, Acc1 Test: 70.26
# L2 Test: 1.0162, Acc2 Test: 51.01
# L3 Test: 1.9195, Acc3 Test: 45.34
# 2019-07-02 16:06:06.182159
# Epoch: 26
# L1 Test: 0.6131, Acc1 Test: 81.08
# L2 Test: 0.5976, Acc2 Test: 75.66
# L3 Test: 1.6616, Acc3 Test: 51.80
# 2019-07-02 16:06:40.106102
# Epoch: 27
# L1 Test: 0.9336, Acc1 Test: 68.83
# L2 Test: 1.0983, Acc2 Test: 54.72
# L3 Test: 2.2567, Acc3 Test: 45.19
# 2019-07-02 16:07:14.431176
# Epoch: 28
# L1 Test: 0.8778, Acc1 Test: 71.87
# L2 Test: 2.5981, Acc2 Test: 51.63
# L3 Test: 2.9509, Acc3 Test: 51.88
# 2019-07-02 16:07:48.377377
# Epoch: 29
# L1 Test: 0.6083, Acc1 Test: 80.69
# L2 Test: 0.3666, Acc2 Test: 88.88
# L3 Test: 2.6393, Acc3 Test: 39.86
# 2019-07-02 16:08:22.253152
# Epoch: 30
# L1 Test: 0.5880, Acc1 Test: 81.63
# L2 Test: 0.6413, Acc2 Test: 61.83
# L3 Test: 1.5696, Acc3 Test: 61.04
# 2019-07-02 16:08:56.217810
# Epoch: 31
# L1 Test: 1.0323, Acc1 Test: 68.03
# L2 Test: 0.7263, Acc2 Test: 71.50
# L3 Test: 2.4029, Acc3 Test: 42.83
# 2019-07-02 16:09:30.390992
# Epoch: 32
# L1 Test: 0.9427, Acc1 Test: 72.93
# L2 Test: 0.4455, Acc2 Test: 82.26
# L3 Test: 2.1823, Acc3 Test: 43.89
# 2019-07-02 16:10:05.166031
# Epoch: 33
# L1 Test: 0.7710, Acc1 Test: 76.14
# L2 Test: 6.1786, Acc2 Test: 48.38
# L3 Test: 2.3524, Acc3 Test: 40.33
# 2019-07-02 16:10:39.664675
# Epoch: 34
# L1 Test: 0.4758, Acc1 Test: 85.51
# L2 Test: 0.5751, Acc2 Test: 63.23
# L3 Test: 1.7947, Acc3 Test: 51.26
# 2019-07-02 16:11:14.145831
# Epoch: 35
# L1 Test: 0.5033, Acc1 Test: 85.04
# L2 Test: 0.9408, Acc2 Test: 65.40
# L3 Test: 1.6018, Acc3 Test: 55.41
# 2019-07-02 16:11:48.747760
# Epoch: 36
# L1 Test: 0.4923, Acc1 Test: 84.81
# L2 Test: 0.9842, Acc2 Test: 52.49
# L3 Test: 1.4436, Acc3 Test: 60.22
# 2019-07-02 16:12:23.445055
# Epoch: 37
# L1 Test: 0.4353, Acc1 Test: 86.91
# L2 Test: 0.6587, Acc2 Test: 64.69
# L3 Test: 2.2158, Acc3 Test: 43.48
# 2019-07-02 16:12:57.428012
# Epoch: 38
# L1 Test: 0.6625, Acc1 Test: 80.20
# L2 Test: 0.9425, Acc2 Test: 51.16
# L3 Test: 2.0998, Acc3 Test: 54.12
# 2019-07-02 16:13:32.342055
# Epoch: 39
# L1 Test: 0.5723, Acc1 Test: 82.56
# L2 Test: 1.2284, Acc2 Test: 31.59
# L3 Test: 1.9466, Acc3 Test: 47.20
# 2019-07-02 16:14:06.761059
# Epoch: 40
# L1 Test: 0.7685, Acc1 Test: 76.86
# L2 Test: 1.1612, Acc2 Test: 36.09
# L3 Test: 3.0036, Acc3 Test: 28.39
# 2019-07-02 16:14:41.373447
# Epoch: 41
# L1 Test: 0.6574, Acc1 Test: 80.30
# L2 Test: 0.3534, Acc2 Test: 84.32
# L3 Test: 1.7810, Acc3 Test: 56.21
# 2019-07-02 16:15:16.036551
# Epoch: 42
# L1 Test: 0.3909, Acc1 Test: 89.08
# L2 Test: 0.2786, Acc2 Test: 88.54
# L3 Test: 2.0281, Acc3 Test: 51.56
# 2019-07-02 16:15:51.655857
# Epoch: 43
# L1 Test: 0.7164, Acc1 Test: 76.98
# L2 Test: 0.7584, Acc2 Test: 57.13
# L3 Test: 1.8403, Acc3 Test: 48.93
# 2019-07-02 16:16:25.805549
# Epoch: 44
# L1 Test: 0.4998, Acc1 Test: 84.51
# L2 Test: 0.5135, Acc2 Test: 81.95
# L3 Test: 1.8572, Acc3 Test: 54.59
# 2019-07-02 16:17:01.091487
# Epoch: 45
# L1 Test: 0.7237, Acc1 Test: 77.56
# L2 Test: 1.0114, Acc2 Test: 52.21
# L3 Test: 1.8034, Acc3 Test: 57.12
# 2019-07-02 16:17:35.408441
# Epoch: 46
# L1 Test: 0.5215, Acc1 Test: 84.22
# L2 Test: 0.4447, Acc2 Test: 79.21
# L3 Test: 2.5156, Acc3 Test: 39.41
# 2019-07-02 16:18:09.544131
# Epoch: 47
# L1 Test: 0.3728, Acc1 Test: 89.09
# L2 Test: 0.3277, Acc2 Test: 86.41
# L3 Test: 2.1617, Acc3 Test: 37.50
# 2019-07-02 16:18:43.867864
# Epoch: 48
# L1 Test: 0.3550, Acc1 Test: 89.87
# L2 Test: 0.4803, Acc2 Test: 73.19
# L3 Test: 1.9695, Acc3 Test: 49.46
# 2019-07-02 16:19:17.861521
# Epoch: 49
# L1 Test: 0.3491, Acc1 Test: 90.57
# L2 Test: 0.3599, Acc2 Test: 81.69
# L3 Test: 2.4518, Acc3 Test: 54.61
# 2019-07-02 16:19:52.128240
# Epoch: 50
# L1 Test: 0.5990, Acc1 Test: 82.07
# L2 Test: 1.5046, Acc2 Test: 24.04
# L3 Test: 3.2232, Acc3 Test: 36.21

# %%
tsne = TSNE(n_components=2, initialization="pca")

print(datetime.datetime.now())

tsne_embedding = tsne.fit(latent_variables)

print(datetime.datetime.now())

plt.figure()
plt.title('Epoch #{}'.format(epoch + 1))
for i in range(len(index) - 1):
    plt.plot(tsne_embedding[index[i]:index[i+1], 0], tsne_embedding[index[i]:index[i+1], 1], '.', alpha=0.5)
plt.legend(['SVHN', 'MNIST'])
plt.show()
# Out:
# 2019-07-02 16:20:26.111897
# 2019-07-02 16:24:15.885659

# %%
plt.figure()
plt.title('Epoch #{}'.format(epoch + 1))
for i in range(1, -1, -1):
    plt.plot(tsne_embedding[index[i]:index[i+1], 0], tsne_embedding[index[i]:index[i+1], 1], '.', alpha=0.5)
plt.legend(['MNIST', 'SVHN'])
plt.show()
